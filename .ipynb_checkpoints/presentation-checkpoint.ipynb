# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(24,16)})
# %matplotlib inline

# %%
df=pd.read_csv("salary.csv")
numeric=pd.read_csv("salary_numeric.csv")
numeric
# Out:
#        age  gender  education    industry  industry_experience        salary
# 0       19    Male         12    business                    0   33640.60752
# 1       21    Male         12    business                    2   43554.24216
# 2       19    Male         12    business                    0   39795.29424
# 3       22    Male         12    business                    1   51102.98856
# 4       21    Male         12    business                    1   32809.57056
# ...    ...     ...        ...         ...                  ...           ...
# 25434   66  Female         18  healthcare                   22  113001.50400
# 25435   61  Female         18  healthcare                   22  122528.73600
# 25436   65  Female         18  healthcare                   33  101398.17600
# 25437   61  Female         18  healthcare                   21   93051.55200
# 25438   63  Female         18  healthcare                   20   90307.00800
#
# [25439 rows x 6 columns]

# %%
sns.displot(data=df, x='salary', kind="kde",  hue='industry')

# %%
sns.scatterplot(data=df, x='industry_experience', y='salary', hue='gender')
# Out:
# <AxesSubplot:xlabel='industry_experience', ylabel='salary'>

# %%
df_male = df.drop(df[df.gender == 'Female'].index)
df_female = df.drop(df[df.gender == 'Male'].index)

# %%
df_male = df_male.drop('gender', axis=1)
df_female = df_female.drop('gender', axis=1)
df_male = df_male.drop('industry', axis=1)
df_female = df_female.drop('industry', axis=1)

# %%
sns.heatmap(data=df_male.corr(), cmap='RdBu_r', annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data=df_female.corr(), cmap='RdBu_r', annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(data=df, x='industry_experience', hue='gender')
# Out:
# <AxesSubplot:xlabel='industry_experience', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='age', hue='gender')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.displot(data=df, x='salary', kind="kde",  hue='gender')
